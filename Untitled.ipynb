# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.path.join("..", "coffee_ratings.csv"))
df.head()
# Out:
#    total_cup_points  species                     owner country_of_origin  \
# 0             90.58  Arabica                 metad plc          Ethiopia
# 1             89.92  Arabica                 metad plc          Ethiopia
# 2             89.75  Arabica  grounds for health admin         Guatemala
# 3             89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
# ...

# %%
df = df.dropna()
df
# Out:
#       total_cup_points  species                         owner  \
# 29               86.58  Arabica        lin, che-hao krude 林哲豪
# 115              84.83  Arabica        lin, che-hao krude 林哲豪
# 125              84.67  Arabica  consejo salvadoreño del café
# 128              84.67  Arabica                  rodrigo soto
# 129              84.67  Arabica     juan luis alvarado romero
# ...                ...      ...                           ...
# 1235             78.00  Arabica        lin, che-hao krude 林哲豪
# 1253             77.33  Arabica               ipanema coffees
# 1308             63.08  Arabica    exportadora atlantic, s.a.
# 1319             82.50  Robusta                nishant gurjer
# 1322             81.58  Robusta                nishant gurjer
#
#      country_of_origin                          farm_name  \
# 29              Taiwan           tsoustructive garden 鄒築園
# 115             Taiwan                  shi fang yuan 十方源
# ...

# %%
# Out:
# <bound method DataFrame.count of       total_cup_points  species                         owner  \
# 29               86.58  Arabica        lin, che-hao krude 林哲豪
# 115              84.83  Arabica        lin, che-hao krude 林哲豪
# 125              84.67  Arabica  consejo salvadoreño del café
# 128              84.67  Arabica                  rodrigo soto
# 129              84.67  Arabica     juan luis alvarado romero
# ...                ...      ...                           ...
# 1235             78.00  Arabica        lin, che-hao krude 林哲豪
# 1253             77.33  Arabica               ipanema coffees
# 1308             63.08  Arabica    exportadora atlantic, s.a.
# 1319             82.50  Robusta                nishant gurjer
# 1322             81.58  Robusta                nishant gurjer
#
#      country_of_origin                          farm_name  \
# 29              Taiwan           tsoustructive garden 鄒築園
# 115             Taiwan                  shi fang yuan 十方源
# ...

# %%
washed_wet = df[df['processing_method'].str.contains("Washed / Wet")]
washed_wet.head()
# Out:
#      total_cup_points  species                         owner  \
# 125             84.67  Arabica  consejo salvadoreño del café
# 128             84.67  Arabica                  rodrigo soto
# 129             84.67  Arabica     juan luis alvarado romero
# 159             84.50  Arabica            ecom japan limited
# 171             84.42  Arabica                   max gurdian
#
#     country_of_origin              farm_name           lot_number  \
# 125       El Salvador              monterrey                 1-71
# 128        Costa Rica              rio jorco              Tarrazu
# 129         Guatemala  san diego buena vista           11/08/0109
# 159            Uganda   kawacom sipi project  035/170/5071146⁠⁠⁠⁠
# 171        Costa Rica        several farmers          5-0015-0231
#
#                       mill           ico_number  \
# 125      j.j. borja nathan            09-392-69
# 128              rio jorco           5-423-0128
# 129  san diego buena vista           11/08/0109
# ...

# %%
washed_wet = washed_wet.reset_index(drop=True)
washed_wet
# Out:
#     index  total_cup_points  species                         owner  \
# 0     125             84.67  Arabica  consejo salvadoreño del café
# 1     128             84.67  Arabica                  rodrigo soto
# 2     129             84.67  Arabica     juan luis alvarado romero
# 3     159             84.50  Arabica            ecom japan limited
# 4     171             84.42  Arabica                   max gurdian
# ..    ...               ...      ...                           ...
# 83   1185             79.17  Arabica          janny marlith torres
# 84   1186             79.17  Arabica     juan luis alvarado romero
# 85   1192             79.08  Arabica     juan luis alvarado romero
# 86   1235             78.00  Arabica        lin, che-hao krude 林哲豪
# 87   1319             82.50  Robusta                nishant gurjer
#
#    country_of_origin                          farm_name  \
# 0        El Salvador                          monterrey
# ...
